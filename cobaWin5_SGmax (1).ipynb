# %%
import csv
from gensim.models import FastText

# Fungsi untuk membaca dataset dalam format CSV
def read_csv_data(filename):
    sentences = []
    with open(filename, 'r') as file:
        reader = csv.reader(file)
        for row in reader:
            sentences.append(row[0].split())
    return sentences

# Membaca dataset dari file CSV
data_file = 'Training_Testing_Data16444.csv'
sentences = read_csv_data(data_file)

# Melatih model FastText dengan metode CBOW
model = FastText(sentences, sg=1, window=5, min_count=2, workers=2, min_n=3, max_n=5)

# Menyimpan model ke dalam file
model_file = 'fasttext_model.bin'
model.save(model_file)

# %%
# Meload model FastText yang telah disimpan
model = FastText.load(model_file)

# Mengambil vektor representasi kata
word = 'anies'
word_vector = model.wv[word]
print(f"Vektor representasi '{word}': {word_vector}")
# Out:
# Vektor representasi 'anies': [-0.59695214 -0.55212104  0.5925334   0.7860149   0.46373895  0.1781849
#   0.1181846   0.36140394  0.15350239 -0.45883042 -0.53470796 -0.13896458
#  -0.4719143  -0.40990147 -0.4022614  -0.19393863  0.7440971  -0.02664791
#   0.17267106 -0.40742853 -0.11780036 -0.24589959 -0.02060308 -0.16776657
#  -0.41754103 -0.32172024  0.43759072 -0.04597335  0.05972001  0.7269833
#  -0.00235381 -0.05343847  0.04065742  0.07221328 -0.4097544   0.53217036
#   0.41212144 -0.2868688   0.7861849  -0.10760847  0.10840602 -0.30481988
#   0.43208882 -0.44089577  0.40012488  0.67397267 -0.29057643  0.01609222
#  -0.42310423 -0.14338003  0.1161981  -0.04976203  0.22002101 -0.27641228
#  -0.02678068 -0.07639357  0.06332961  0.18461761 -0.01710188 -0.1718569
#   0.3167047   0.03828599 -0.2971529  -0.04613828  0.02477175  0.34113932
#   0.4024863   0.4164661   0.06912603  0.35517734  0.08121601  0.36983687
#  -0.05965924 -0.43860385  0.7385774   0.35323033 -0.40388393 -0.5950906
#   0.10449792  0.5128443   0.29159707 -0.8194186   0.27326253  0.01189621
#  -0.30252713 -0.05225829 -0.08554998 -0.31890157  0.32248864 -0.77146137
#  -0.22123562  0.5959388   0.43059853 -0.35266793  0.10948766  0.24659285
#   0.4207077   0.04693783  0.1332697   0.03473357]

# %%
import numpy as np
from sklearn.model_selection import train_test_split

#import the required library
import pandas as pd

from keras.utils import to_categorical
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import LabelEncoder
from keras.models import Sequential
from keras.layers import Dense,MaxPooling1D
from keras.layers import LSTM, Flatten, Dropout, Conv1D, Input
from tensorflow.keras.layers import Embedding
from keras.preprocessing import sequence
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing import sequence
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing import sequence
from sklearn.model_selection import train_test_split
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Embedding, Conv1D, AveragePooling1D, GlobalAveragePooling1D, Dropout, LSTM, concatenate
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import regularizers

# %%
# Baca dataset tweet ke dalam DataFrame
df = pd.read_csv('Training_Testing_Data16444.csv')

# Preprocessing teks jika diperlukan
df['text'] = df['text'].str.lower()

# # Gabungkan label dan teks ke dalam satu kolom dengan format yang diperlukan
# df['fasttext_input'] = '__label__' + df['Label'].astype(str) + ' ' + df['text']

# %%
# Assuming 'text' is the column containing the text data in your DataFrame
texts = df['text'].tolist()

# Initialize the tokenizer
tokenizer = Tokenizer()

# Fit the tokenizer on the texts
tokenizer.fit_on_texts(texts)

# Limit the tokenizer vocabulary to the top n words
top_n = 10000  # Set the desired number of top words
tokenizer.num_words = top_n

# Convert texts to sequences of integers
sequences = tokenizer.texts_to_sequences(texts)

# %%
# Hitung panjang maksimum dari sequences
max_length = max(len(seq) for seq in sequences)
print("Maximum sequence length:", max_length)
# Out:
# Maximum sequence length: 250

# %%
# Assuming 'label' is the column containing the corresponding labels in your DataFrame
labels = df['Label'].tolist()

# Pad sequences to a fixed length
max_sequence_length = max_length  # Set the maximum sequence length based on the shape of X_train
# Set the desired maximum sequence length
padded_sequences = pad_sequences(sequences, maxlen=max_sequence_length)

# Split the data into training, validation, and test sets
X_train, X_test, y_train, y_test = train_test_split(padded_sequences, labels, test_size=0.25, random_state=42)

# Split the training data further into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Print the vocabulary size
vocab_size = min(top_n, len(tokenizer.word_index)) + 1
print("Vocabulary size:", vocab_size)
# Out:
# Vocabulary size: 10001

# %%
import numpy as np

# Define a function to encode labels and handle unseen labels
def encode_labels(labels, classes):
    encoded_labels = np.zeros((len(labels), len(classes)))
    for i, label in enumerate(labels):
        if label in classes:
            encoded_labels[i, classes.index(label)] = 1
        else:
            encoded_labels[i, 0] = 1  # Assign unseen labels to the first class
    return encoded_labels

# Define the classes based on the unique labels in the original label list
classes = np.unique(labels).tolist()

# Encode labels for training, validation, and test sets
y_train = encode_labels(y_train, classes)
y_val = encode_labels(y_val, classes)
y_test = encode_labels(y_test, classes)

# %%
print("Shape of train data:", X_train.shape)
print("Shape of Test data:", X_test.shape)
print("Shape of CV data:", X_val.shape)
# Out:
# Shape of train data: (59198, 250)
# Shape of Test data: (24666, 250)
# Shape of CV data: (14800, 250)

# %%
import csv
from gensim.models import FastText
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Embedding, Conv1D, MaxPooling1D, GlobalMaxPooling1D, Dropout, LSTM, concatenate, Flatten
from tensorflow.keras import regularizers
import numpy as np

# Fungsi untuk membaca dataset dalam format CSV
def read_csv_data(filename):
    sentences = []
    with open(filename, 'r') as file:
        reader = csv.reader(file)
        for row in reader:
            sentences.append(row[0].split())
    return sentences

# Membaca dataset dari file CSV
data_file = 'Training_Testing_Data16444.csv'
sentences = read_csv_data(data_file)

# Melatih model FastText dengan metode CBOW
model = FastText(sentences, sg=1, window=5, min_count=2, workers=2, min_n=3, max_n=5)

# Menyimpan model ke dalam file
model_file = 'fasttext_model.bin'
model.save(model_file)

# Load the pre-trained FastText model
fasttext_model = FastText.load(model_file)

# Get the word vectors
word_vectors = fasttext_model.wv.vectors

# Create the embedding matrix
vocab_size = word_vectors.shape[0]
embedding_vector_length = word_vectors.shape[1]
embedding_matrix = np.zeros((vocab_size, embedding_vector_length))
word_index = {word: idx for idx, word in enumerate(fasttext_model.wv.index_to_key)}
for word, index in word_index.items():
    embedding_matrix[index] = word_vectors[index]

# Define the model architecture
max_sequence_length = 250
input_layer = Input(shape=(max_sequence_length,))
embedding_layer = Embedding(input_dim=vocab_size, output_dim=embedding_vector_length, weights=[embedding_matrix], input_length=max_sequence_length, trainable=False)(input_layer)

# CNN Layers
cnn_layer1 = Conv1D(128, kernel_size=3, activation='relu')(embedding_layer)
cnn_layer1 = MaxPooling1D(pool_size=2)(cnn_layer1)
cnn_layer2 = Conv1D(128, kernel_size=4, activation='relu')(embedding_layer)
cnn_layer2 = MaxPooling1D(pool_size=2)(cnn_layer2)
cnn_layer3 = Conv1D(128, kernel_size=5, activation='relu')(embedding_layer)
cnn_layer3 = MaxPooling1D(pool_size=2)(cnn_layer3)
cnn_layer1 = GlobalMaxPooling1D()(cnn_layer1)
cnn_layer2 = GlobalMaxPooling1D()(cnn_layer2)
cnn_layer3 = GlobalMaxPooling1D()(cnn_layer3)
cnn_layer = concatenate([cnn_layer1, cnn_layer2, cnn_layer3])
cnn_layer = Dropout(0.5)(cnn_layer)
cnn_layer = Dense(16, activation='relu', kernel_regularizer=regularizers.l2(0.01))(cnn_layer)
cnn_layer = Dropout(0.5)(cnn_layer)

# LSTM Layer
lstm_layer = LSTM(64)(embedding_layer)
lstm_layer = Dropout(0.5)(lstm_layer)

# Embedding Layer
embedding_only_layer = Flatten()(embedding_layer)
embedding_only_layer = Dropout(0.5)(embedding_only_layer)
embedding_only_layer = Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.01))(embedding_only_layer)
embedding_only_layer = Dropout(0.5)(embedding_only_layer)

# Concatenate all layers
merged_layer = concatenate([cnn_layer, lstm_layer, embedding_only_layer])
merged_layer = Dropout(0.5)(merged_layer)
output_layer = Dense(6, activation='softmax')(merged_layer)

# Create the model
model = Model(inputs=input_layer, outputs=output_layer)

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 250)]        0           []
#
#  embedding (Embedding)          (None, 250, 100)     3095500     ['input_1[0][0]']
#
#  conv1d (Conv1D)                (None, 248, 128)     38528       ['embedding[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 247, 128)     51328       ['embedding[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 246, 128)     64128       ['embedding[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 124, 128)     0           ['conv1d[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 123, 128)    0           ['conv1d_1[0][0]']
#
#  max_pooling1d_2 (MaxPooling1D)  (None, 123, 128)    0           ['conv1d_2[0][0]']
#
#  global_max_pooling1d (GlobalMa  (None, 128)         0           ['max_pooling1d[0][0]']
#  xPooling1D)
#
#  global_max_pooling1d_1 (Global  (None, 128)         0           ['max_pooling1d_1[0][0]']
#  MaxPooling1D)
#
#  global_max_pooling1d_2 (Global  (None, 128)         0           ['max_pooling1d_2[0][0]']
#  MaxPooling1D)
#
#  concatenate (Concatenate)      (None, 384)          0           ['global_max_pooling1d[0][0]',
#                                                                   'global_max_pooling1d_1[0][0]',
#                                                                   'global_max_pooling1d_2[0][0]']
#
#  flatten (Flatten)              (None, 25000)        0           ['embedding[0][0]']
#
#  dropout (Dropout)              (None, 384)          0           ['concatenate[0][0]']
#
#  dropout_3 (Dropout)            (None, 25000)        0           ['flatten[0][0]']
#
#  dense (Dense)                  (None, 16)           6160        ['dropout[0][0]']
#
#  lstm (LSTM)                    (None, 64)           42240       ['embedding[0][0]']
#
#  dense_1 (Dense)                (None, 128)          3200128     ['dropout_3[0][0]']
#
#  dropout_1 (Dropout)            (None, 16)           0           ['dense[0][0]']
#
#  dropout_2 (Dropout)            (None, 64)           0           ['lstm[0][0]']
#
#  dropout_4 (Dropout)            (None, 128)          0           ['dense_1[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 208)          0           ['dropout_1[0][0]',
#                                                                   'dropout_2[0][0]',
#                                                                   'dropout_4[0][0]']
#
#  dropout_5 (Dropout)            (None, 208)          0           ['concatenate_1[0][0]']
#
#  dense_2 (Dense)                (None, 6)            1254        ['dropout_5[0][0]']
#
# ==================================================================================================
# Total params: 6,499,266
# Trainable params: 3,403,766
# Non-trainable params: 3,095,500
# __________________________________________________________________________________________________
# None

# %%
# Pad sequences to a fixed length
max_sequence_length = max_length  # Set the maximum sequence length based on the shape of X_train
# Set the desired maximum sequence length
padded_sequences = pad_sequences(sequences, maxlen=max_sequence_length)
# # Set the desired maximum sequence length
padded_sequences = pad_sequences(sequences, maxlen=max_sequence_length)
# Split the data into training, validation, and test sets
X_train, X_test, y_train, y_test = train_test_split(padded_sequences, labels, test_size=0.25, random_state=42)

# Split the training data further into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Print the shapes of the data splits
print("Shape of train data:", X_train.shape)
print("Shape of validation data:", X_val.shape)
print("Shape of test data:", X_test.shape)
print("Shape of train labels:", len(y_train))
print("Shape of validation labels:", len(y_val))
print("Shape of test labels:", len(y_test))

from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical

# Encode class labels with integers
label_encoder = LabelEncoder()
label_encoder.fit(labels)
y_train_encoded = label_encoder.transform(y_train)
y_val_encoded = label_encoder.transform(y_val)
y_test_encoded = label_encoder.transform(y_test)

# Convert labels to one-hot encoded format
num_classes = len(label_encoder.classes_)
y_train_encoded = to_categorical(y_train_encoded, num_classes)
y_val_encoded = to_categorical(y_val_encoded, num_classes)
y_test_encoded = to_categorical(y_test_encoded, num_classes)

# Train the model with early stopping
batch_size = 1024
epochs = 100

# Train the model with early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=3)
history = model.fit(X_train, y_train_encoded, batch_size=batch_size, epochs=epochs,
                    validation_data=(X_val, y_val_encoded), verbose=1,
                    callbacks=[early_stopping])

# Evaluate the model on training, validation, and test data
train_loss, train_accuracy = model.evaluate(X_train, y_train_encoded, verbose=0)
val_loss, val_accuracy = model.evaluate(X_val, y_val_encoded, verbose=0)
test_loss, test_accuracy = model.evaluate(X_test, y_test_encoded, verbose=0)
print(f"Train Loss: {train_loss:.4f}")
print(f"Train Accuracy: {train_accuracy:.4f}")
print(f"Validation Loss: {val_loss:.4f}")
print(f"Validation Accuracy: {val_accuracy:.4f}")
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# Shape of train data: (59198, 250)
# Shape of validation data: (14800, 250)
# Shape of test data: (24666, 250)
# Shape of train labels: 59198
# Shape of validation labels: 14800
# Shape of test labels: 24666
# Epoch 1/100
# 58/58 [==============================] - 481s 8s/step - loss: 3.6758 - accuracy: 0.1947 - val_loss: 2.5240 - val_accuracy: 0.2400
# Epoch 2/100
# 58/58 [==============================] - 478s 8s/step - loss: 2.2222 - accuracy: 0.2396 - val_loss: 1.9986 - val_accuracy: 0.2928
# Epoch 3/100
# 58/58 [==============================] - 479s 8s/step - loss: 1.8892 - accuracy: 0.2817 - val_loss: 1.7760 - val_accuracy: 0.3241
# Epoch 4/100
# 58/58 [==============================] - 475s 8s/step - loss: 1.7266 - accuracy: 0.3170 - val_loss: 1.6425 - val_accuracy: 0.3537
# Epoch 5/100
# 58/58 [==============================] - 472s 8s/step - loss: 1.6320 - accuracy: 0.3473 - val_loss: 1.5717 - val_accuracy: 0.3755
# Epoch 6/100
# 58/58 [==============================] - 472s 8s/step - loss: 1.5732 - accuracy: 0.3645 - val_loss: 1.5129 - val_accuracy: 0.4039
# Epoch 7/100
# 58/58 [==============================] - 469s 8s/step - loss: 1.5614 - accuracy: 0.3822 - val_loss: 1.4973 - val_accuracy: 0.4189
# Epoch 8/100
# 58/58 [==============================] - 478s 8s/step - loss: 1.5083 - accuracy: 0.4054 - val_loss: 1.4332 - val_accuracy: 0.4314
# Epoch 9/100
# 58/58 [==============================] - 518s 9s/step - loss: 1.4644 - accuracy: 0.4188 - val_loss: 1.3992 - val_accuracy: 0.4447
# Epoch 10/100
# 58/58 [==============================] - 471s 8s/step - loss: 1.4369 - accuracy: 0.4321 - val_loss: 1.3725 - val_accuracy: 0.4533
# Epoch 11/100
# 58/58 [==============================] - 468s 8s/step - loss: 1.4127 - accuracy: 0.4429 - val_loss: 1.3435 - val_accuracy: 0.4722
# Epoch 12/100
# 58/58 [==============================] - 477s 8s/step - loss: 1.3914 - accuracy: 0.4505 - val_loss: 1.3273 - val_accuracy: 0.4770
# Epoch 13/100
# 58/58 [==============================] - 473s 8s/step - loss: 1.3731 - accuracy: 0.4598 - val_loss: 1.3040 - val_accuracy: 0.4868
# Epoch 14/100
# 58/58 [==============================] - 471s 8s/step - loss: 1.3524 - accuracy: 0.4680 - val_loss: 1.2998 - val_accuracy: 0.4878
# Epoch 15/100
# 58/58 [==============================] - 469s 8s/step - loss: 1.3399 - accuracy: 0.4730 - val_loss: 1.2736 - val_accuracy: 0.4998
# Epoch 16/100
# 58/58 [==============================] - 471s 8s/step - loss: 1.3178 - accuracy: 0.4849 - val_loss: 1.2487 - val_accuracy: 0.5082
# Epoch 17/100
# 58/58 [==============================] - 469s 8s/step - loss: 1.3014 - accuracy: 0.4934 - val_loss: 1.2365 - val_accuracy: 0.5137
# Epoch 18/100
# 58/58 [==============================] - 470s 8s/step - loss: 1.2924 - accuracy: 0.4952 - val_loss: 1.2218 - val_accuracy: 0.5248
# Epoch 19/100
# 58/58 [==============================] - 472s 8s/step - loss: 1.2747 - accuracy: 0.5049 - val_loss: 1.2171 - val_accuracy: 0.5241
# Epoch 20/100
# 58/58 [==============================] - 476s 8s/step - loss: 1.2612 - accuracy: 0.5098 - val_loss: 1.1940 - val_accuracy: 0.5362
# Epoch 21/100
# 58/58 [==============================] - 475s 8s/step - loss: 1.2484 - accuracy: 0.5135 - val_loss: 1.1903 - val_accuracy: 0.5351
# Epoch 22/100
# 58/58 [==============================] - 476s 8s/step - loss: 1.2424 - accuracy: 0.5194 - val_loss: 1.1782 - val_accuracy: 0.5437
# Epoch 23/100
# 58/58 [==============================] - 475s 8s/step - loss: 1.2359 - accuracy: 0.5206 - val_loss: 1.1797 - val_accuracy: 0.5413
# Epoch 24/100
# 58/58 [==============================] - 476s 8s/step - loss: 1.2261 - accuracy: 0.5265 - val_loss: 1.1585 - val_accuracy: 0.5536
# Epoch 25/100
# 58/58 [==============================] - 469s 8s/step - loss: 1.2106 - accuracy: 0.5316 - val_loss: 1.1435 - val_accuracy: 0.5590
# Epoch 26/100
# 58/58 [==============================] - 472s 8s/step - loss: 1.1946 - accuracy: 0.5372 - val_loss: 1.1399 - val_accuracy: 0.5618
# Epoch 27/100
# 58/58 [==============================] - 473s 8s/step - loss: 1.1911 - accuracy: 0.5404 - val_loss: 1.1267 - val_accuracy: 0.5692
# Epoch 28/100
# 58/58 [==============================] - 472s 8s/step - loss: 1.1820 - accuracy: 0.5444 - val_loss: 1.1132 - val_accuracy: 0.5727
# Epoch 29/100
# 58/58 [==============================] - 576s 10s/step - loss: 1.1756 - accuracy: 0.5478 - val_loss: 1.1142 - val_accuracy: 0.5730
# Epoch 30/100
# 58/58 [==============================] - 541s 9s/step - loss: 1.1695 - accuracy: 0.5484 - val_loss: 1.0995 - val_accuracy: 0.5779
# Epoch 31/100
# 58/58 [==============================] - 557s 10s/step - loss: 1.1780 - accuracy: 0.5459 - val_loss: 1.1225 - val_accuracy: 0.5654
# Epoch 32/100
# 58/58 [==============================] - 555s 10s/step - loss: 1.1642 - accuracy: 0.5507 - val_loss: 1.0929 - val_accuracy: 0.5818
# Epoch 33/100
# 58/58 [==============================] - 511s 9s/step - loss: 1.1483 - accuracy: 0.5585 - val_loss: 1.0914 - val_accuracy: 0.5799
# Epoch 34/100
# 58/58 [==============================] - 536s 9s/step - loss: 1.1426 - accuracy: 0.5643 - val_loss: 1.0780 - val_accuracy: 0.5932
# Epoch 35/100
# 58/58 [==============================] - 547s 9s/step - loss: 1.1319 - accuracy: 0.5671 - val_loss: 1.0682 - val_accuracy: 0.5922
# Epoch 36/100
# 58/58 [==============================] - 551s 10s/step - loss: 1.1304 - accuracy: 0.5677 - val_loss: 1.0639 - val_accuracy: 0.5923
# Epoch 37/100
# 58/58 [==============================] - 503s 9s/step - loss: 1.1166 - accuracy: 0.5747 - val_loss: 1.0548 - val_accuracy: 0.5973
# Epoch 38/100
# 58/58 [==============================] - 548s 9s/step - loss: 1.1113 - accuracy: 0.5768 - val_loss: 1.0589 - val_accuracy: 0.5955
# Epoch 39/100
# 58/58 [==============================] - 567s 10s/step - loss: 1.1119 - accuracy: 0.5765 - val_loss: 1.0667 - val_accuracy: 0.5940
# Epoch 40/100
# 58/58 [==============================] - 542s 9s/step - loss: 1.1077 - accuracy: 0.5760 - val_loss: 1.0419 - val_accuracy: 0.6058
# Epoch 41/100
# 58/58 [==============================] - 556s 10s/step - loss: 1.0974 - accuracy: 0.5812 - val_loss: 1.0500 - val_accuracy: 0.6022
# Epoch 42/100
# 58/58 [==============================] - 570s 10s/step - loss: 1.0973 - accuracy: 0.5819 - val_loss: 1.0414 - val_accuracy: 0.6010
# Epoch 43/100
# 58/58 [==============================] - 567s 10s/step - loss: 1.0874 - accuracy: 0.5853 - val_loss: 1.0343 - val_accuracy: 0.6042
# Epoch 44/100
# 58/58 [==============================] - 558s 10s/step - loss: 1.0782 - accuracy: 0.5907 - val_loss: 1.0255 - val_accuracy: 0.6118
# Epoch 45/100
# 58/58 [==============================] - 568s 10s/step - loss: 1.0701 - accuracy: 0.5918 - val_loss: 1.0270 - val_accuracy: 0.6112
# Epoch 46/100
# 58/58 [==============================] - 551s 10s/step - loss: 1.0685 - accuracy: 0.5935 - val_loss: 1.0170 - val_accuracy: 0.6123
# Epoch 47/100
# 58/58 [==============================] - 550s 10s/step - loss: 1.0692 - accuracy: 0.5935 - val_loss: 1.0275 - val_accuracy: 0.6054
# Epoch 48/100
# 58/58 [==============================] - 519s 9s/step - loss: 1.0636 - accuracy: 0.5962 - val_loss: 1.0122 - val_accuracy: 0.6139
# Epoch 49/100
# 58/58 [==============================] - 553s 10s/step - loss: 1.0517 - accuracy: 0.6018 - val_loss: 1.0076 - val_accuracy: 0.6174
# Epoch 50/100
# 58/58 [==============================] - 515s 9s/step - loss: 1.0501 - accuracy: 0.6017 - val_loss: 1.0053 - val_accuracy: 0.6176
# Epoch 51/100
# 58/58 [==============================] - 554s 10s/step - loss: 1.0440 - accuracy: 0.6055 - val_loss: 0.9981 - val_accuracy: 0.6222
# Epoch 52/100
# 58/58 [==============================] - 500s 9s/step - loss: 1.0408 - accuracy: 0.6079 - val_loss: 0.9957 - val_accuracy: 0.6219
# Epoch 53/100
# 58/58 [==============================] - 540s 9s/step - loss: 1.0395 - accuracy: 0.6063 - val_loss: 1.0028 - val_accuracy: 0.6193
# Epoch 54/100
# 58/58 [==============================] - 559s 10s/step - loss: 1.0364 - accuracy: 0.6090 - val_loss: 0.9922 - val_accuracy: 0.6249
# Epoch 55/100
# 58/58 [==============================] - 569s 10s/step - loss: 1.0302 - accuracy: 0.6100 - val_loss: 0.9901 - val_accuracy: 0.6248
# Epoch 56/100
# 58/58 [==============================] - 561s 10s/step - loss: 1.0301 - accuracy: 0.6114 - val_loss: 0.9941 - val_accuracy: 0.6233
# Epoch 57/100
# 58/58 [==============================] - 552s 10s/step - loss: 1.0218 - accuracy: 0.6147 - val_loss: 0.9810 - val_accuracy: 0.6276
# Epoch 58/100
# 58/58 [==============================] - 543s 9s/step - loss: 1.0159 - accuracy: 0.6161 - val_loss: 0.9796 - val_accuracy: 0.6304
# Epoch 59/100
# 58/58 [==============================] - 563s 10s/step - loss: 1.0113 - accuracy: 0.6200 - val_loss: 0.9744 - val_accuracy: 0.6300
# Epoch 60/100
# 58/58 [==============================] - 548s 9s/step - loss: 1.0102 - accuracy: 0.6196 - val_loss: 0.9692 - val_accuracy: 0.6350
# Epoch 61/100
# 58/58 [==============================] - 545s 9s/step - loss: 1.0113 - accuracy: 0.6195 - val_loss: 0.9735 - val_accuracy: 0.6341
# Epoch 62/100
# 58/58 [==============================] - 554s 10s/step - loss: 1.0037 - accuracy: 0.6230 - val_loss: 0.9786 - val_accuracy: 0.6299
# Epoch 63/100
# 58/58 [==============================] - 548s 9s/step - loss: 1.0050 - accuracy: 0.6235 - val_loss: 0.9633 - val_accuracy: 0.6366
# Epoch 64/100
# 58/58 [==============================] - 546s 9s/step - loss: 0.9954 - accuracy: 0.6266 - val_loss: 0.9641 - val_accuracy: 0.6390
# Epoch 65/100
# 58/58 [==============================] - 505s 9s/step - loss: 0.9888 - accuracy: 0.6273 - val_loss: 0.9821 - val_accuracy: 0.6381
# Epoch 66/100
# 58/58 [==============================] - 549s 9s/step - loss: 0.9977 - accuracy: 0.6290 - val_loss: 0.9685 - val_accuracy: 0.6378
# Train Loss: 0.8719
# Train Accuracy: 0.6724
# Validation Loss: 0.9685
# Validation Accuracy: 0.6378
# Test Loss: 0.9772
# Test Accuracy: 0.6318

# %%
import matplotlib.pyplot as plt

# Retrieve training history
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

# Plot accuracy curves
epochs = range(1, len(train_accuracy) + 1)
plt.plot(epochs, train_accuracy, 'bo-', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'ro-', label='Validation Accuracy')
plt.axhline(y=test_accuracy, color='g', linestyle='--', label='Test Accuracy')
plt.title('Training, Validation, and Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Ambil data akurasi pelatihan, validasi, dan testing dari history
epochs = range(1, len(history.history['accuracy']) + 1)
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
test_accuracy = history.history['test_accuracy']

# Plot grafik akurasi pelatihan, validasi, dan testing
plt.plot(epochs, train_accuracy, 'b', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'r', label='Validation Accuracy')
plt.plot(epochs, test_accuracy, 'g', label='Testing Accuracy')
plt.title('Training, Validation, and Testing Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

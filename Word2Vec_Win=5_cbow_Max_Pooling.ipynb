# %%
import csv
from gensim.models import FastText

# Fungsi untuk membaca dataset dalam format CSV
def read_csv_data(filename):
    sentences = []
    with open(filename, 'r') as file:
        reader = csv.reader(file)
        for row in reader:
            sentences.append(row[0].split())
    return sentences

# Membaca dataset dari file CSV
data_file = 'Training_Testing_Data16444.csv'
sentences = read_csv_data(data_file)

# Melatih model FastText dengan metode CBOW
model = FastText(sentences, sg=0, window=5, min_count=2, workers=2, min_n=3, max_n=5)

# Menyimpan model ke dalam file
model_file = 'fasttext_model.bin'
model.save(model_file)

# %%
# Meload model FastText yang telah disimpan
model = FastText.load(model_file)

# Mengambil vektor representasi kata
word = 'anies'
word_vector = model.wv[word]
print(f"Vektor representasi '{word}': {word_vector}")
# Out:
# Vektor representasi 'anies': [-2.3911245  -1.3296605   0.56258196  0.46012735 -0.01349307  0.4147209
#  -0.27709353 -0.3878214  -0.2504481  -1.4164249  -0.12547031 -1.0483876
#  -1.3052245  -1.5928948  -1.1405779  -2.4078493   0.6788398   0.1825234
#  -0.17193596 -1.4256158  -2.1206431  -2.2208922  -0.48990387  0.27553597
#   0.06156152 -1.9507716   0.5867547   0.54821706 -0.48912156  2.0211911
#  -1.095217   -0.26790562 -0.37968922 -0.19061194  0.08687614  0.36301062
#   1.7554018  -0.52873886  1.3775823  -1.2268248   0.00753131  0.6494149
#  -0.11377709 -1.4060422   1.6971818   1.5810108   1.2542489   2.2456365
#  -0.5289007   1.2387949  -0.0633033   1.0602705   0.61364037 -1.5682323
#  -0.2834815  -0.40528128 -0.5887392   0.79310745  0.34835953 -0.47878376
#   0.94216436  0.46124667 -2.0413961  -2.0626762  -0.7755639  -0.72816783
#   1.8291285   0.7069213   1.1693046   0.3727471  -0.5386972  -0.23157693
#  -0.5700557  -0.75132173 -0.36727974  0.18045078 -2.0360913   0.15254667
#  -0.0762517  -0.7292214   3.0708292  -0.81469345  0.6831845  -0.65240616
#  -0.43918994 -0.8884463   1.4708664  -0.35271513  0.36851183 -1.2531421
#  -0.76205957  1.0096215   0.48277524 -0.9566219  -0.183074    0.23073886
#   1.4991975  -2.900312    0.52869946 -0.6421678 ]

# %%
import numpy as np
from sklearn.model_selection import train_test_split

#import the required library
import numpy as np

from keras.utils import to_categorical
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import LabelEncoder
from keras.models import Sequential
from keras.layers import Dense,MaxPooling1D
from keras.layers import LSTM, Flatten, Dropout, Conv1D, Input
from tensorflow.keras.layers import Embedding
from keras.preprocessing import sequence
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing import sequence
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing import sequence
from sklearn.model_selection import train_test_split
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Embedding, Conv1D, AveragePooling1D, GlobalAveragePooling1D, Dropout, LSTM, concatenate
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import regularizers
import pandas as pd

# %%
# Baca dataset tweet ke dalam DataFrame
df = pd.read_csv('Training_Testing_Data16444.csv')

# Preprocessing teks jika diperlukan
df['text'] = df['text'].str.lower()

# # Gabungkan label dan teks ke dalam satu kolom dengan format yang diperlukan
# df['fasttext_input'] = '__label__' + df['Label'].astype(str) + ' ' + df['text']

# %%
# Assuming 'text' is the column containing the text data in your DataFrame
texts = df['text'].tolist()

# Initialize the tokenizer
tokenizer = Tokenizer()

# Fit the tokenizer on the texts
tokenizer.fit_on_texts(texts)

# Limit the tokenizer vocabulary to the top n words
top_n = 10000  # Set the desired number of top words
tokenizer.num_words = top_n

# Convert texts to sequences of integers
sequences = tokenizer.texts_to_sequences(texts)

# %%
# Hitung panjang maksimum dari sequences
max_length = max(len(seq) for seq in sequences)
print("Maximum sequence length:", max_length)
# Out:
# Maximum sequence length: 250

# %%
# Assuming 'label' is the column containing the corresponding labels in your DataFrame
labels = df['Label'].tolist()

# Pad sequences to a fixed length
max_sequence_length = max_length  # Set the maximum sequence length based on the shape of X_train
# Set the desired maximum sequence length
padded_sequences = pad_sequences(sequences, maxlen=max_sequence_length)

# Split the data into training, validation, and test sets
X_train, X_test, y_train, y_test = train_test_split(padded_sequences, labels, test_size=0.25, random_state=42)

# Split the training data further into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Print the vocabulary size
vocab_size = min(top_n, len(tokenizer.word_index)) + 1
print("Vocabulary size:", vocab_size)
# Out:
# Vocabulary size: 10001

# %%
import numpy as np

# Define a function to encode labels and handle unseen labels
def encode_labels(labels, classes):
    encoded_labels = np.zeros((len(labels), len(classes)))
    for i, label in enumerate(labels):
        if label in classes:
            encoded_labels[i, classes.index(label)] = 1
        else:
            encoded_labels[i, 0] = 1  # Assign unseen labels to the first class
    return encoded_labels

# Define the classes based on the unique labels in the original label list
classes = np.unique(labels).tolist()

# Encode labels for training, validation, and test sets
y_train = encode_labels(y_train, classes)
y_val = encode_labels(y_val, classes)
y_test = encode_labels(y_test, classes)

# %%
print("Shape of train data:", X_train.shape)
print("Shape of Test data:", X_test.shape)
print("Shape of CV data:", X_val.shape)
# Out:
# Shape of train data: (59198, 250)
# Shape of Test data: (24666, 250)
# Shape of CV data: (14800, 250)

# %%
import csv
from gensim.models import FastText
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Embedding, Conv1D, MaxPooling1D, GlobalMaxPooling1D, Dropout, LSTM, concatenate, Flatten
from tensorflow.keras import regularizers
import numpy as np

# Fungsi untuk membaca dataset dalam format CSV
def read_csv_data(filename):
    sentences = []
    with open(filename, 'r') as file:
        reader = csv.reader(file)
        for row in reader:
            sentences.append(row[0].split())
    return sentences

# Membaca dataset dari file CSV
data_file = 'Training_Testing_Data16444.csv'
sentences = read_csv_data(data_file)

# Melatih model FastText dengan metode CBOW
model = FastText(sentences, sg=0, window=5, min_count=2, workers=2, min_n=3, max_n=5)

# Menyimpan model ke dalam file
model_file = 'fasttext_model.bin'
model.save(model_file)

# Load the pre-trained FastText model
fasttext_model = FastText.load(model_file)

# Get the word vectors
word_vectors = fasttext_model.wv.vectors

# Create the embedding matrix
vocab_size = word_vectors.shape[0]
embedding_vector_length = word_vectors.shape[1]
embedding_matrix = np.zeros((vocab_size, embedding_vector_length))
word_index = {word: idx for idx, word in enumerate(fasttext_model.wv.index_to_key)}
for word, index in word_index.items():
    embedding_matrix[index] = word_vectors[index]

# Define the model architecture
max_sequence_length = 250
input_layer = Input(shape=(max_sequence_length,))
embedding_layer = Embedding(input_dim=vocab_size, output_dim=embedding_vector_length, weights=[embedding_matrix], input_length=max_sequence_length, trainable=False)(input_layer)

# CNN Layers
cnn_layer1 = Conv1D(128, kernel_size=3, activation='relu')(embedding_layer)
cnn_layer1 = MaxPooling1D(pool_size=2)(cnn_layer1)
cnn_layer2 = Conv1D(128, kernel_size=4, activation='relu')(embedding_layer)
cnn_layer2 = MaxPooling1D(pool_size=2)(cnn_layer2)
cnn_layer3 = Conv1D(128, kernel_size=5, activation='relu')(embedding_layer)
cnn_layer3 = MaxPooling1D(pool_size=2)(cnn_layer3)
cnn_layer1 = GlobalMaxPooling1D()(cnn_layer1)
cnn_layer2 = GlobalMaxPooling1D()(cnn_layer2)
cnn_layer3 = GlobalMaxPooling1D()(cnn_layer3)
cnn_layer = concatenate([cnn_layer1, cnn_layer2, cnn_layer3])
cnn_layer = Dropout(0.5)(cnn_layer)
cnn_layer = Dense(16, activation='relu', kernel_regularizer=regularizers.l2(0.01))(cnn_layer)
cnn_layer = Dropout(0.5)(cnn_layer)

# LSTM Layer
lstm_layer = LSTM(64)(embedding_layer)
lstm_layer = Dropout(0.5)(lstm_layer)

# Embedding Layer
embedding_only_layer = Flatten()(embedding_layer)
embedding_only_layer = Dropout(0.5)(embedding_only_layer)
embedding_only_layer = Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.01))(embedding_only_layer)
embedding_only_layer = Dropout(0.5)(embedding_only_layer)

# Concatenate all layers
merged_layer = concatenate([cnn_layer, lstm_layer, embedding_only_layer])
merged_layer = Dropout(0.5)(merged_layer)
output_layer = Dense(6, activation='softmax')(merged_layer)

# Create the model
model = Model(inputs=input_layer, outputs=output_layer)

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 250)]        0           []
#
#  embedding (Embedding)          (None, 250, 100)     3095500     ['input_1[0][0]']
#
#  conv1d (Conv1D)                (None, 248, 128)     38528       ['embedding[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 247, 128)     51328       ['embedding[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 246, 128)     64128       ['embedding[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 124, 128)     0           ['conv1d[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 123, 128)    0           ['conv1d_1[0][0]']
#
#  max_pooling1d_2 (MaxPooling1D)  (None, 123, 128)    0           ['conv1d_2[0][0]']
#
#  global_max_pooling1d (GlobalMa  (None, 128)         0           ['max_pooling1d[0][0]']
#  xPooling1D)
#
#  global_max_pooling1d_1 (Global  (None, 128)         0           ['max_pooling1d_1[0][0]']
#  MaxPooling1D)
#
#  global_max_pooling1d_2 (Global  (None, 128)         0           ['max_pooling1d_2[0][0]']
#  MaxPooling1D)
#
#  concatenate (Concatenate)      (None, 384)          0           ['global_max_pooling1d[0][0]',
#                                                                   'global_max_pooling1d_1[0][0]',
#                                                                   'global_max_pooling1d_2[0][0]']
#
#  flatten (Flatten)              (None, 25000)        0           ['embedding[0][0]']
#
#  dropout (Dropout)              (None, 384)          0           ['concatenate[0][0]']
#
#  dropout_3 (Dropout)            (None, 25000)        0           ['flatten[0][0]']
#
#  dense (Dense)                  (None, 16)           6160        ['dropout[0][0]']
#
#  lstm (LSTM)                    (None, 64)           42240       ['embedding[0][0]']
#
#  dense_1 (Dense)                (None, 128)          3200128     ['dropout_3[0][0]']
#
#  dropout_1 (Dropout)            (None, 16)           0           ['dense[0][0]']
#
#  dropout_2 (Dropout)            (None, 64)           0           ['lstm[0][0]']
#
#  dropout_4 (Dropout)            (None, 128)          0           ['dense_1[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 208)          0           ['dropout_1[0][0]',
#                                                                   'dropout_2[0][0]',
#                                                                   'dropout_4[0][0]']
#
#  dropout_5 (Dropout)            (None, 208)          0           ['concatenate_1[0][0]']
#
#  dense_2 (Dense)                (None, 6)            1254        ['dropout_5[0][0]']
#
# ==================================================================================================
# Total params: 6,499,266
# Trainable params: 3,403,766
# Non-trainable params: 3,095,500
# __________________________________________________________________________________________________
# None

# %%
# Pad sequences to a fixed length
max_sequence_length = max_length  # Set the maximum sequence length based on the shape of X_train
# Set the desired maximum sequence length
padded_sequences = pad_sequences(sequences, maxlen=max_sequence_length)
# # Set the desired maximum sequence length
padded_sequences = pad_sequences(sequences, maxlen=max_sequence_length)
# Split the data into training, validation, and test sets
X_train, X_test, y_train, y_test = train_test_split(padded_sequences, labels, test_size=0.25, random_state=42)

# Split the training data further into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Print the shapes of the data splits
print("Shape of train data:", X_train.shape)
print("Shape of validation data:", X_val.shape)
print("Shape of test data:", X_test.shape)
print("Shape of train labels:", len(y_train))
print("Shape of validation labels:", len(y_val))
print("Shape of test labels:", len(y_test))

from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical

# Encode class labels with integers
label_encoder = LabelEncoder()
label_encoder.fit(labels)
y_train_encoded = label_encoder.transform(y_train)
y_val_encoded = label_encoder.transform(y_val)
y_test_encoded = label_encoder.transform(y_test)

# Convert labels to one-hot encoded format
num_classes = len(label_encoder.classes_)
y_train_encoded = to_categorical(y_train_encoded, num_classes)
y_val_encoded = to_categorical(y_val_encoded, num_classes)
y_test_encoded = to_categorical(y_test_encoded, num_classes)

# Train the model with early stopping
batch_size = 1024
epochs = 100

# Train the model with early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=3)
history = model.fit(X_train, y_train_encoded, batch_size=batch_size, epochs=epochs,
                    validation_data=(X_val, y_val_encoded), verbose=1,
                    callbacks=[early_stopping])

# Evaluate the model on training, validation, and test data
train_loss, train_accuracy = model.evaluate(X_train, y_train_encoded, verbose=0)
val_loss, val_accuracy = model.evaluate(X_val, y_val_encoded, verbose=0)
test_loss, test_accuracy = model.evaluate(X_test, y_test_encoded, verbose=0)
print(f"Train Loss: {train_loss:.4f}")
print(f"Train Accuracy: {train_accuracy:.4f}")
print(f"Validation Loss: {val_loss:.4f}")
print(f"Validation Accuracy: {val_accuracy:.4f}")
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# Shape of train data: (59198, 250)
# Shape of validation data: (14800, 250)
# Shape of test data: (24666, 250)
# Shape of train labels: 59198
# Shape of validation labels: 14800
# Shape of test labels: 24666
# Epoch 1/100
# 58/58 [==============================] - 505s 9s/step - loss: 5.1032 - accuracy: 0.1944 - val_loss: 3.3881 - val_accuracy: 0.2492
# Epoch 2/100
# 58/58 [==============================] - 495s 9s/step - loss: 2.9603 - accuracy: 0.2413 - val_loss: 2.5839 - val_accuracy: 0.2811
# Epoch 3/100
# 58/58 [==============================] - 491s 8s/step - loss: 2.3872 - accuracy: 0.2714 - val_loss: 2.1880 - val_accuracy: 0.3053
# Epoch 4/100
# 58/58 [==============================] - 529s 9s/step - loss: 2.0844 - accuracy: 0.2953 - val_loss: 1.9381 - val_accuracy: 0.3367
# Epoch 5/100
# 58/58 [==============================] - 484s 8s/step - loss: 1.8877 - accuracy: 0.3218 - val_loss: 1.7725 - val_accuracy: 0.3643
# Epoch 6/100
# 58/58 [==============================] - 484s 8s/step - loss: 1.7581 - accuracy: 0.3409 - val_loss: 1.6593 - val_accuracy: 0.3855
# Epoch 7/100
# 58/58 [==============================] - 479s 8s/step - loss: 1.6633 - accuracy: 0.3652 - val_loss: 1.5855 - val_accuracy: 0.3931
# Epoch 8/100
# 58/58 [==============================] - 477s 8s/step - loss: 1.6027 - accuracy: 0.3758 - val_loss: 1.5282 - val_accuracy: 0.4143
# Epoch 9/100
# 58/58 [==============================] - 478s 8s/step - loss: 1.5552 - accuracy: 0.3878 - val_loss: 1.4845 - val_accuracy: 0.4270
# Epoch 10/100
# 58/58 [==============================] - 480s 8s/step - loss: 1.5209 - accuracy: 0.3966 - val_loss: 1.4508 - val_accuracy: 0.4351
# Epoch 11/100
# 58/58 [==============================] - 482s 8s/step - loss: 1.4965 - accuracy: 0.4063 - val_loss: 1.4208 - val_accuracy: 0.4499
# Epoch 12/100
# 58/58 [==============================] - 481s 8s/step - loss: 1.4611 - accuracy: 0.4187 - val_loss: 1.4214 - val_accuracy: 0.4468
# Epoch 13/100
# 58/58 [==============================] - 480s 8s/step - loss: 1.4542 - accuracy: 0.4213 - val_loss: 1.3790 - val_accuracy: 0.4594
# Epoch 14/100
# 58/58 [==============================] - 475s 8s/step - loss: 1.4252 - accuracy: 0.4312 - val_loss: 1.3607 - val_accuracy: 0.4625
# Epoch 15/100
# 58/58 [==============================] - 481s 8s/step - loss: 1.4115 - accuracy: 0.4349 - val_loss: 1.3432 - val_accuracy: 0.4743
# Epoch 16/100
# 58/58 [==============================] - 481s 8s/step - loss: 1.3997 - accuracy: 0.4410 - val_loss: 1.3325 - val_accuracy: 0.4731
# Epoch 17/100
# 58/58 [==============================] - 479s 8s/step - loss: 1.3853 - accuracy: 0.4480 - val_loss: 1.3301 - val_accuracy: 0.4697
# Epoch 18/100
# 58/58 [==============================] - 480s 8s/step - loss: 1.3773 - accuracy: 0.4506 - val_loss: 1.3263 - val_accuracy: 0.4715
# Epoch 19/100
# 58/58 [==============================] - 480s 8s/step - loss: 1.3715 - accuracy: 0.4555 - val_loss: 1.3049 - val_accuracy: 0.4893
# Epoch 20/100
# 58/58 [==============================] - 481s 8s/step - loss: 1.3599 - accuracy: 0.4592 - val_loss: 1.2999 - val_accuracy: 0.4877
# Epoch 21/100
# 58/58 [==============================] - 478s 8s/step - loss: 1.3489 - accuracy: 0.4647 - val_loss: 1.2946 - val_accuracy: 0.4893
# Epoch 22/100
# 58/58 [==============================] - 480s 8s/step - loss: 1.3427 - accuracy: 0.4667 - val_loss: 1.2789 - val_accuracy: 0.4964
# Epoch 23/100
# 58/58 [==============================] - 482s 8s/step - loss: 1.3334 - accuracy: 0.4719 - val_loss: 1.2799 - val_accuracy: 0.4953
# Epoch 24/100
# 58/58 [==============================] - 478s 8s/step - loss: 1.3332 - accuracy: 0.4722 - val_loss: 1.2720 - val_accuracy: 0.4967
# Epoch 25/100
# 58/58 [==============================] - 479s 8s/step - loss: 1.3202 - accuracy: 0.4791 - val_loss: 1.2651 - val_accuracy: 0.5002
# Epoch 26/100
# 58/58 [==============================] - 482s 8s/step - loss: 1.3175 - accuracy: 0.4795 - val_loss: 1.2547 - val_accuracy: 0.5055
# Epoch 27/100
# 58/58 [==============================] - 481s 8s/step - loss: 1.3126 - accuracy: 0.4822 - val_loss: 1.2545 - val_accuracy: 0.5098
# Epoch 28/100
# 58/58 [==============================] - 483s 8s/step - loss: 1.3018 - accuracy: 0.4854 - val_loss: 1.2566 - val_accuracy: 0.5097
# Epoch 29/100
# 58/58 [==============================] - 484s 8s/step - loss: 1.2988 - accuracy: 0.4857 - val_loss: 1.2465 - val_accuracy: 0.5168
# Epoch 30/100
# 58/58 [==============================] - 480s 8s/step - loss: 1.2892 - accuracy: 0.4908 - val_loss: 1.2325 - val_accuracy: 0.5171
# Epoch 31/100
# 58/58 [==============================] - 479s 8s/step - loss: 1.2890 - accuracy: 0.4933 - val_loss: 1.2363 - val_accuracy: 0.5142
# Epoch 32/100
# 58/58 [==============================] - 482s 8s/step - loss: 1.2828 - accuracy: 0.4952 - val_loss: 1.2374 - val_accuracy: 0.5129
# Epoch 33/100
# 58/58 [==============================] - 483s 8s/step - loss: 1.2784 - accuracy: 0.4974 - val_loss: 1.2233 - val_accuracy: 0.5186
# Epoch 34/100
# 58/58 [==============================] - 484s 8s/step - loss: 1.2730 - accuracy: 0.5006 - val_loss: 1.2165 - val_accuracy: 0.5203
# Epoch 35/100
# 58/58 [==============================] - 484s 8s/step - loss: 1.2679 - accuracy: 0.5024 - val_loss: 1.2240 - val_accuracy: 0.5204
# Epoch 36/100
# 58/58 [==============================] - 484s 8s/step - loss: 1.2601 - accuracy: 0.5055 - val_loss: 1.2263 - val_accuracy: 0.5245
# Epoch 37/100
# 58/58 [==============================] - 483s 8s/step - loss: 1.2745 - accuracy: 0.5005 - val_loss: 1.2097 - val_accuracy: 0.5195
# Epoch 38/100
# 58/58 [==============================] - 484s 8s/step - loss: 1.2558 - accuracy: 0.5082 - val_loss: 1.2017 - val_accuracy: 0.5241
# Epoch 39/100
# 58/58 [==============================] - 483s 8s/step - loss: 1.2537 - accuracy: 0.5088 - val_loss: 1.2046 - val_accuracy: 0.5276
# Epoch 40/100
# 58/58 [==============================] - 484s 8s/step - loss: 1.2469 - accuracy: 0.5132 - val_loss: 1.1952 - val_accuracy: 0.5301
# Epoch 41/100
# 58/58 [==============================] - 484s 8s/step - loss: 1.2416 - accuracy: 0.5160 - val_loss: 1.1933 - val_accuracy: 0.5322
# Epoch 42/100
# 58/58 [==============================] - 484s 8s/step - loss: 1.2389 - accuracy: 0.5149 - val_loss: 1.1904 - val_accuracy: 0.5295
# Epoch 43/100
# 58/58 [==============================] - 481s 8s/step - loss: 1.2382 - accuracy: 0.5146 - val_loss: 1.1880 - val_accuracy: 0.5336
# Epoch 44/100
# 58/58 [==============================] - 477s 8s/step - loss: 1.2358 - accuracy: 0.5190 - val_loss: 1.1844 - val_accuracy: 0.5327
# Epoch 45/100
# 58/58 [==============================] - 477s 8s/step - loss: 1.2285 - accuracy: 0.5192 - val_loss: 1.2061 - val_accuracy: 0.5151
# Epoch 46/100
# 58/58 [==============================] - 482s 8s/step - loss: 1.2279 - accuracy: 0.5216 - val_loss: 1.1834 - val_accuracy: 0.5384
# Epoch 47/100
# 58/58 [==============================] - 482s 8s/step - loss: 1.2249 - accuracy: 0.5217 - val_loss: 1.1827 - val_accuracy: 0.5397
# Epoch 48/100
# 58/58 [==============================] - 483s 8s/step - loss: 1.2308 - accuracy: 0.5147 - val_loss: 1.1775 - val_accuracy: 0.5385
# Epoch 49/100
# 58/58 [==============================] - 476s 8s/step - loss: 1.2143 - accuracy: 0.5263 - val_loss: 1.1727 - val_accuracy: 0.5414
# Epoch 50/100
# 58/58 [==============================] - 473s 8s/step - loss: 1.2163 - accuracy: 0.5261 - val_loss: 1.1764 - val_accuracy: 0.5390
# Epoch 51/100
# 58/58 [==============================] - 463s 8s/step - loss: 1.2111 - accuracy: 0.5283 - val_loss: 1.1743 - val_accuracy: 0.5425
# Epoch 52/100
# 58/58 [==============================] - 463s 8s/step - loss: 1.2054 - accuracy: 0.5293 - val_loss: 1.1637 - val_accuracy: 0.5422
# Epoch 53/100
# 58/58 [==============================] - 464s 8s/step - loss: 1.2022 - accuracy: 0.5313 - val_loss: 1.1662 - val_accuracy: 0.5412
# Epoch 54/100
# 58/58 [==============================] - 463s 8s/step - loss: 1.2044 - accuracy: 0.5319 - val_loss: 1.1644 - val_accuracy: 0.5451
# Epoch 55/100
# 58/58 [==============================] - 461s 8s/step - loss: 1.1948 - accuracy: 0.5355 - val_loss: 1.1555 - val_accuracy: 0.5481
# Epoch 56/100
# 58/58 [==============================] - 461s 8s/step - loss: 1.1960 - accuracy: 0.5354 - val_loss: 1.1567 - val_accuracy: 0.5474
# Epoch 57/100
# 58/58 [==============================] - 461s 8s/step - loss: 1.1881 - accuracy: 0.5372 - val_loss: 1.1545 - val_accuracy: 0.5482
# Epoch 58/100
# 58/58 [==============================] - 461s 8s/step - loss: 1.1888 - accuracy: 0.5359 - val_loss: 1.1526 - val_accuracy: 0.5487
# Epoch 59/100
# 58/58 [==============================] - 463s 8s/step - loss: 1.1879 - accuracy: 0.5386 - val_loss: 1.1514 - val_accuracy: 0.5493
# Epoch 60/100
# 58/58 [==============================] - 460s 8s/step - loss: 1.1785 - accuracy: 0.5407 - val_loss: 1.1458 - val_accuracy: 0.5528
# Epoch 61/100
# 58/58 [==============================] - 461s 8s/step - loss: 1.1859 - accuracy: 0.5383 - val_loss: 1.1498 - val_accuracy: 0.5485
# Epoch 62/100
# 58/58 [==============================] - 461s 8s/step - loss: 1.1782 - accuracy: 0.5414 - val_loss: 1.1488 - val_accuracy: 0.5518
# Epoch 63/100
# 58/58 [==============================] - 461s 8s/step - loss: 1.1776 - accuracy: 0.5437 - val_loss: 1.1488 - val_accuracy: 0.5484
# Train Loss: 1.0738
# Train Accuracy: 0.5850
# Validation Loss: 1.1488
# Validation Accuracy: 0.5484
# Test Loss: 1.1622
# Test Accuracy: 0.5435

# %%
import matplotlib.pyplot as plt

# Retrieve training history
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

# Plot accuracy curves
epochs = range(1, len(train_accuracy) + 1)
plt.plot(epochs, train_accuracy, 'bo-', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'ro-', label='Validation Accuracy')
plt.axhline(y=test_accuracy, color='g', linestyle='--', label='Test Accuracy')
plt.title('Training, Validation, and Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
